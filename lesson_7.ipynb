# %% [markdown]
# **Задание**
# 1. Попробуйте обучить нейронную сеть GRU/LSTM для предсказания сентимента сообщений с твитера на примере https://www.kaggle.com/datasets/arkhoshghalb/twitter-sentiment-analysis-hatred-speech
#
# 2. Опишите, какой результат вы получили? Что помогло вам улучшить ее точность?

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.5.18.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
# !pip install stop-words pymorphy2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: stop-words in /usr/local/lib/python3.7/dist-packages (2018.7.23)
# Requirement already satisfied: pymorphy2 in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.7.2)

# %%
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-03a87ddd-fe82-47ab-80f1-9908f2fd1b39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03a87ddd-fe82-47ab-80f1-9908f2fd1b39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 68 bytes

# %%
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes         36           False
# gan-getting-started                            2030-07-01 23:59:00  Getting Started     Prizes        135           False
# store-sales-time-series-forecasting            2030-06-30 23:59:00  Getting Started  Knowledge        640           False
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge        125           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       1678           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      13969           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       4278           False
# connectx                                       2030-01-01 00:00:00  Getting Started  Knowledge        210           False
# nlp-getting-started                            2030-01-01 00:00:00  Getting Started  Knowledge        977           False
# spaceship-titanic                              2030-01-01 00:00:00  Getting Started  Knowledge       2187           False
# competitive-data-science-predict-future-sales  2022-12-31 23:59:00  Playground           Kudos      14919           False
# amex-default-prediction                        2022-08-24 23:59:00  Featured          $100,000        964           False
# feedback-prize-effectiveness                   2022-08-23 23:59:00  Featured           $55,000        236           False
# AI4Code                                        2022-08-11 23:59:00  Featured          $150,000        501           False
# smartphone-decimeter-2022                      2022-07-29 23:59:00  Research           $10,000        244           False
# ubiquant-market-prediction                     2022-07-18 23:59:00  Featured          $100,000       2356           False
# uw-madison-gi-tract-image-segmentation         2022-07-14 23:59:00  Research           $25,000       1037           False
# kore-2022                                      2022-07-12 23:59:00  Featured           $15,000        322           False
# foursquare-location-matching                   2022-07-07 23:59:00  Featured           $25,000        814           False
# jpx-tokyo-stock-exchange-prediction            2022-07-05 23:59:00  Featured           $63,000       1513           False

# %%
# !kaggle datasets download -d kirillkoncha/russian-illegal-drugs-reviews-sentiment-dataset
# Out:
# russian-illegal-drugs-reviews-sentiment-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from string import punctuation

from pymorphy2 import MorphAnalyzer
import re
import nltk
nltk.download('wordnet')
nltk.download("punkt")
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !unzip '/content/russian-illegal-drugs-reviews-sentiment-dataset.zip'
# Out:
# Archive:  /content/russian-illegal-drugs-reviews-sentiment-dataset.zip
# replace data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data.csv

# %%
import pandas as pd

#загрузка данных
df_train = pd.read_csv('/content/data.csv', encoding='utf-8',sep=';', error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_train['sentiment'].value_counts()
# Out:
# -1    601
#  1    599
# Name: sentiment, dtype: int64

# %%
df_train['sentiment'].where(~(df_train.sentiment<0), other=0, inplace=True)

# %%
df_train['sentiment'].value_counts()
# Out:
# 0    601
# 1    599
# Name: sentiment, dtype: int64

# %%
df_train.head()
# Out:
#                                              content  sentiment
# 0  Был ненаход (клад похоронили под слоем бетона)...          1
# 1  10/10/10 хорошая прогулка, за хорошим феном. Д...          1
# 2  Дома,соточки по всем параметрам,спасибо всей к...          1
# 3           Все супер, квест момент, Стафф как надо!          1
# 4                                         всё хорошо          1

# %%
train, validate, test = np.split(df_train, [int(.7*len(df_train)), int(.85*len(df_train))])

# %%
sw = set(get_stop_words("ru"))
puncts = set(punctuation)
morpher = MorphAnalyzer()


def preprocess_text(txt):
    txt = str(txt)
    txt = "".join(c for c in txt if c not in puncts)
    txt = txt.lower()
    txt = re.sub("не\s", "не", txt)
    txt = [morpher.parse(word)[0].normal_form for word in txt.split() if word not in sw]
    return " ".join(txt)

# %%
print(sw)
# Out:
# {'и', 'будут', 'этого', 'вот', 'очень', 'иметь', 'есть', 'суть', 'мож', 'уметь', 'каждые', 'снова', 'шестнадцать', 'тем', 'самом', 'при', 'вы', 'моё', 'говорил', 'ними', 'недалеко', 'этой', 'во', 'миллионов', 'кроме', 'другой', 'ты', 'без', 'давно', 'эти', 'хоть', 'затем', 'почему', 'чем', 'тысяч', 'всего', 'пять', 'алло', 'году', 'самой', 'сказала', 'близко', 'ничего', 'вверх', 'тобою', 'ею', 'занята', 'внизу', 'двадцатый', 'других', 'самому', 'теперь', 'сейчас', 'одной', 'время', 'больше', 'говорит', 'иногда', 'действительно', 'по', 'наиболее', 'заняты', 'год', 'вокруг', 'хотеть', 'против', 'тех', 'мною', 'другое', 'такая', 'тринадцать', 'туда', 'он', 'свои', 'десятый', 'всё', 'через', 'об', 'прекрасно', 'нее', 'ком', 'раз', 'всеми', 'наша', 'важные', 'это', 'шестой', 'люди', 'вами', 'нельзя', 'ещё', 'отсюда', 'каждое', 'восемнадцать', 'сам', 'сказал', 'что', 'будем', 'тут', 'одного', 'пятнадцать', 'значит', 'ведь', 'от', 'мог', 'для', 'вся', 'человек', 'четырнадцатый', 'чтобы', 'весь', 'ниже', 'может', 'даром', 'раньше', 'нередко', 'девятнадцатый', 'позже', 'за', 'назад', 'совсем', 'себя', 'первый', 'ваша', 'своего', 'чему', 'т', 'ему', 'часто', 'девятый', 'ваш', 'своих', 'непрерывно', 'седьмой', 'где', 'этим', 'будь', 'везде', 'почти', 'можно', 'должно', 'два', 'моя', 'именно', 'само', 'даже', 'твоя', 'они', 'также', 'многочисленное', 'быть', 'у', 'теми', 'сколько', 'ее', 'тот', 'мной', 'так', 'слишком', 'буду', 'самих', 'тою', 'двенадцатый', 'будешь', 'ну', 'такие', 'свою', 'семнадцатый', 'десять', 'восьмой', 'имя', 'мои', 'перед', 'одиннадцатый', 'мало', 'до', 'всегда', 'сначала', 'то', 'кто', 'твой', 'её', 'можхо', 'этом', 'их', 'его', 'ваши', 'самим', 'собою', 'ту', 'как', 'хотя', 'вдруг', 'года', 'а', 'со', 'девять', 'которой', 'нх', 'мочь', 'но', 'наконец', 'нем', 'всю', 'я', 'нам', 'которые', 'вдали', 'долго', 'разве', 'чтоб', 'на', 'много', 'такое', 'отовсюду', 'лет', 'самого', 'многочисленная', 'день', 'могут', 'твоё', 'хорошо', 'недавно', 'еще', 'дальше', 'тебя', 'каждый', 'третий', 'кому', 'впрочем', 'никогда', 'занято', 'лишь', 'неё', 'мой', 'жизнь', 'или', 'многочисленный', 'ей', 'которых', 'которая', 'девятнадцать', 'две', 'оба', 'семь', 'этот', 'который', 'кем', 'него', 'вон', 'спасибо', 'более', 'посреди', 'сих', 'низко', 'потому', 'мы', 'важная', 'здесь', 'всему', 'которого', 'какая', 'г', 'надо', 'им', 'дел', 'тебе', 'всюду', 'процентов', 'пор', 'наши', 'каждая', 'далеко', 'была', 'был', 'свое', 'все', 'нас', 'рано', 'бывь', 'однако', 'нет', 'одиннадцать', 'двенадцать', 'никуда', 'три', 'чего', 'двадцать', 'с', 'один', 'бывает', 'уж', 'к', 'эту', 'кого', 'не', 'там', 'кругом', 'меня', 'наше', 'них', 'начала', 'стал', 'в', 'да', 'пора', 'конечно', 'пятнадцатый', 'рядом', 'ней', 'тому', 'мира', 'нею', 'та', 'она', 'те', 'важное', 'этих', 'обычно', 'времени', 'ни', 'когда', 'сказать', 'мор', 'меля', 'другая', 'чаще', 'сегодня', 'потом', 'будто', 'занят', 'чуть', 'ими', 'около', 'куда', 'том', 'довольно', 'меньше', 'ваше', 'шестнадцатый', 'зато', 'было', 'своей', 'пожалуйста', 'друго', 'лучше', 'будет', 'собой', 'вас', 'наверху', 'эта', 'если', 'другие', 'четыре', 'над', 'ж', 'вам', 'четвертый', 'просто', 'под', 'тринадцатый', 'оно', 'всем', 'себе', 'тогда', 'важный', 'этими', 'нибудь', 'мимо', 'наш', 'из', 'восемнадцатый', 'второй', 'будете', 'особенно', 'про', 'всех', 'после', 'пятый', 'вниз', 'многочисленные', 'м', 'двух', 'зачем', 'сами', 'хочешь', 'немного', 'четырнадцать', 'нами', 'того', 'этому', 'только', 'такой', 'нему', 'пока', 'шесть', 'несколько', 'между', 'тобой', 'саму', 'бы', 'были', 'менее', 'уже', 'однажды', 'какой', 'тоже', 'сеаой', 'всею', 'мне', 'ли', 'нужно', 'сама', 'самими', 'о', 'же', 'е', 'семнадцать', 'восемь', 'опять', 'кажется'}

# %%
from tqdm import tqdm 
tqdm.pandas()

train['content'] = train['content'].progress_apply(preprocess_text)
validate['content'] = validate['content'].progress_apply(preprocess_text)
test['content'] = test['content'].progress_apply(preprocess_text)
# Out:
# 100%|██████████| 840/840 [00:02<00:00, 335.45it/s]
# 100%|██████████| 180/180 [00:00<00:00, 390.38it/s]
# 100%|██████████| 180/180 [00:00<00:00, 465.62it/s]

# %%
train_corpus = " ".join(train["content"])
train_corpus = train_corpus.lower()

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download("punkt")

tokens = word_tokenize(train_corpus)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tokens[:10]
# Out:
# ['ненаход',
#  'клад',
#  'похоронить',
#  'слой',
#  'бетон',
#  'максимально',
#  'вежливый',
#  'поддержка',
#  'купончик',
#  'магазин']

# %%
tokens_filtered = [word for word in tokens if word.isalnum()]
print(tokens_filtered)
# Out:
# ['ненаход', 'клад', 'похоронить', 'слой', 'бетон', 'максимально', 'вежливый', 'поддержка', 'купончик', 'магазин', 'порешать', 'вопрос', '1010', '101010', 'хороший', 'прогулка', 'хороший', 'фен', 'новый', 'встреча', 'домасоточка', 'параметрамспасибо', 'весь', 'командерекомендовать', 'данный', 'шопперебрать', 'магазовдостойный', 'качество', 'тутёща', 'зайдунеотказаться', 'купонавсем', 'добро', 'супер', 'квест', 'момент', 'стаффа', 'касание', 'купить', 'забрать', 'сожрал101010', 'общий', 'видимо', 'момент', 'решить', 'сделать', 'заказ', 'попасть', 'параллельный', 'вселенная', 'чётко', 'быстро', 'восторженный', 'отзыв', 'страница', 'правда', 'передать', 'свой', 'опыт', 'отзыв', 'общий', 'очередной', 'попых', 'пытаться', 'закинуть', 'деньга', 'очередной', 'покупка', 'нерассчитать', 'комиссия', 'тд', 'итог', 'нехватать', '000002этый', '70р', 'курс', '100', 'обмен', 'гидра', 'вонючий', 'биток', '2гр', 'клад', 'наркоман', 'деньга', 'писать', 'магазин', 'просьба', 'купонить', 'сумма', 'получать', 'ответ', 'течение', '10', 'минута', 'купон', '150', 'рубасовый', 'радость', 'покупать', 'закладуля', 'еда', 'они', 'оч', 'крутой', 'тайник', 'ясно', 'понятно', 'курьер', '4', 'фотография', 'место', 'панорамный', 'видно', 'пройти', 'вблизи', 'точно', 'указанный', 'точка', 'лежать', 'хороший', 'качество', 'сверху', 'развернуть', 'описание', 'текст', 'кароч', 'приехать', 'стемнеть', 'место', 'уличный', 'свет', 'сразу', 'сориентировалсяблаго', 'фотка', 'курьер', 'абсолютный', 'темя', 'фонарик', 'касание', 'снять', 'заклад', 'сунуть', 'рука', 'указать', 'нить', 'ход', 'упаковка', 'добротный', 'вес', 'глаз', 'правда', '2гр', 'тайник', 'оч', 'крутой', 'беспалевный', 'качество', 'судить', 'написать', 'правда', 'качество', 'около', 'общий', 'вернуться', 'сюда', 'итак', 'джентльмен', 'отписать', 'магазин', 'лс', 'приз', 'ежедневный', 'конкурс', 'выдать', 'купон', '1000', 'рубль', 'нерай', 'вообще', 'касание', 'стаффа', 'хороший', 'отлично', 'магазин', 'процветание', 'качество', 'огонь', 'место', 'неудачный', 'отдел', 'полиция', 'экипаж', 'проехать', 'прийтись', 'сидеть', 'тачка', 'выжидать', 'касание', 'чётко', 'магазин', 'км', 'респект', 'непонимать', 'остальной', 'магазин', 'немочь', 'чётко', 'работать', 'приятно', 'удивляться', 'кура', 'молодчик', 'советовать', 'незря', 'магаз', 'список', 'качество', 'нетоп', 'деньга', 'стоить', 'найти', 'проблема', 'клад', 'надёжный', 'место', 'живописный', 'комар', 'пидарас', 'гэнгбэнг', 'дорого', 'охуенно', 'есто', 'найти', 'быстро', 'спрятать', 'специфический', 'запах', 'влага', 'пакет', 'испаряться', 'моментально', 'попадание', 'воздух', 'целое', 'стаффа', 'рабочий', 'респект', 'снятой', 'касание', 'стаффа', 'бомба', 'брать', 'непервый', 'довольный', 'клад', 'касание', 'стаффа', 'слабоватый', 'upd', 'неслабый', 'действовать', 'мягко', 'приятный', 'хороший', 'стим', 'перегиб', 'сильный', 'танец', 'челюсть', 'отлично', 'данный', 'шоп', 'работать', 'адекватный', 'ответливый', 'идти', 'встреча', 'онлайн', 'работа', 'данный', 'шоп', 'рекомендовать', 'смело', 'ненаход', 'магазин', 'выслушать', 'выдать', 'адрес', 'вообще', 'уровнеобращаться', 'сюда', 'качество', 'условие', 'достойный', '101010', 'чётко', '101010', 'снятой', 'касание', 'стаффа', 'запах', 'вкус', 'подумать', 'наебаловый', 'дорога', 'распидорасить', 'конкретно', 'км', 'красава', 'такой', 'чёткий', 'описание', 'нигде', 'невидеть', 'правда', 'далековато', 'идти', 'целое', 'покупка', 'довольный', 'пункт', '10', 'балл', 'обязательно', 'заглянуть', 'магазин', 'нераз', 'удача', 'магазин', 'процветание', 'супер', 'возникнуть', 'трудность', 'магазин', 'пойти', 'уступка', 'стафа', 'супер', 'добро', 'ненаход', 'крайнедолгий', 'диспут', 'результат', 'прислать', 'решение', 'целое', 'норма', 'место', '10упаковка', '10', 'качество', 'достойный', 'гуд', 'левый', 'право', 'перепутать', 'гуд', 'качество', 'вроде', 'норма', 'лихний', 'запах', 'вкус', 'найтись', 'квест', 'интересный', 'км', 'красава', '7', 'балл', 'изз', 'малый', 'вес', 'заявить', 'ровно', '5', 'вместе', 'ж ...

# %%
max_words = 20000
max_len = 10
num_classes = 1

# обучение
epochs = 10
batch_size = 512
print_batch_n = 100

# %%
#соберем max_words наиболее частых токенов

#частотное распределение: как часто встречается каждый токен в tokens_filtered
dist = FreqDist(tokens_filtered)
dist
# Out:
# FreqDist({'ненаход': 199,
#           'клад': 259,
#           'похоронить': 1,
#           'слой': 3,
#           'бетон': 1,
#           'максимально': 5,
#           'вежливый': 4,
#           'поддержка': 10,
#           'купончик': 7,
#           'магазин': 252,
#           'порешать': 1,
#           'вопрос': 17,
#           '1010': 21,
#           '101010': 45,
#           'хороший': 86,
#           'прогулка': 7,
#           'фен': 6,
#           'новый': 16,
#           'встреча': 22,
#           'домасоточка': 1,
#           'параметрамспасибо': 1,
#           'весь': 6,
#           'командерекомендовать': 1,
#           'данный': 29,
#           'шопперебрать': 1,
#           'магазовдостойный': 1,
#           'качество': 126,
#           'тутёща': 1,
#           'зайдунеотказаться': 1,
#           'купонавсем': 1,
#           'добро': 17,
#           'супер': 17,
#           'квест': 43,
#           'момент': 7,
#           'стаффа': 43,
#           'касание': 115,
#           'купить': 23,
#           'забрать': 65,
#           'сожрал101010': 1,
#           'общий': 17,
#           'видимо': 10,
#           'решить': 33,
#           'сделать': 44,
#           'заказ': 17,
#           'попасть': 7,
#           'параллельный': 3,
#           'вселенная': 1,
#           'чётко': 33,
#           'быстро': 33,
#           'восторженный': 1,
#           'отзыв': 31,
#           'страница': 1,
#           'правда': 12,
#           'передать': 1,
#           'свой': 17,
#           'опыт': 10,
#           'очередной': 8,
#           'попых': 1,
#           'пытаться': 5,
#           'закинуть': 5,
#           'деньга': 48,
#           'покупка': 53,
#           'нерассчитать': 1,
#           'комиссия': 2,
#           'тд': 2,
#           'итог': 31,
#           'нехватать': 8,
#           '000002этый': 1,
#           '70р': 1,
#           'курс': 5,
#           '100': 9,
#           'обмен': 1,
#           'гидра': 6,
#           'вонючий': 1,
#           'биток': 3,
#           '2гр': 4,
#           'наркоман': 1,
#           'писать': 9,
#           'просьба': 6,
#           'купонить': 2,
#           'сумма': 6,
#           'получать': 3,
#           'ответ': 10,
#           'течение': 3,
#           '10': 85,
#           'минута': 20,
#           'купон': 36,
#           '150': 2,
#           'рубасовый': 1,
#           'радость': 1,
#           'покупать': 16,
#           'закладуля': 1,
#           'еда': 2,
#           'они': 4,
#           'оч': 5,
#           'крутой': 8,
#           'тайник': 18,
#           'ясно': 1,
#           'понятно': 3,
#           'курьер': 39,
#           '4': 19,
#           'фотография': 4,
#           'место': 291,
#           'панорамный': 1,
#           'видно': 11,
#           'пройти': 11,
#           'вблизи': 1,
#           'точно': 13,
#           'указанный': 7,
#           'точка': 15,
#           'лежать': 12,
#           'сверху': 3,
#           'развернуть': 4,
#           'описание': 37,
#           'текст': 1,
#           'кароч': 2,
#           'приехать': 12,
#           'стемнеть': 1,
#           'уличный': 1,
#           'свет': 2,
#           'сразу': 35,
#           'сориентировалсяблаго': 1,
#           'фотка': 21,
#           'абсолютный': 1,
#           'темя': 1,
#           'фонарик': 2,
#           'снять': 35,
#           'заклад': 3,
#           'сунуть': 1,
#           'рука': 16,
#           'указать': 12,
#           'нить': 5,
#           'ход': 5,
#           'упаковка': 21,
#           'добротный': 2,
#           'вес': 45,
#           'глаз': 7,
#           'беспалевный': 1,
#           'судить': 6,
#           'написать': 11,
#           'около': 12,
#           'вернуться': 8,
#           'сюда': 23,
#           'итак': 2,
#           'джентльмен': 1,
#           'отписать': 2,
#           'лс': 1,
#           'приз': 1,
#           'ежедневный': 1,
#           'конкурс': 1,
#           'выдать': 16,
#           '1000': 2,
#           'рубль': 2,
#           'нерай': 1,
#           'вообще': 31,
#           'отлично': 20,
#           'процветание': 17,
#           'огонь': 12,
#           'неудачный': 2,
#           'отдел': 1,
#           'полиция': 5,
#           'экипаж': 1,
#           'проехать': 3,
#           'прийтись': 31,
#           'сидеть': 7,
#           'тачка': 1,
#           'выжидать': 1,
#           'км': 27,
#           'респект': 30,
#           'непонимать': 3,
#           'остальной': 14,
#           'немочь': 16,
#           'работать': 12,
#           'приятно': 11,
#           'удивляться': 2,
#           'кура': 21,
#           'молодчик': 1,
#           'советовать': 23,
#           'незря': 2,
#           'магаз': 27,
#           'список': 1,
#           'нетоп': 1,
#           'стоить': 15,
#           'найти': 68,
#           'проблема': 52,
#           'надёжный': 13,
#           'живописный': 3,
#           'комар': 2,
#           'пидарас': 4,
#           'гэнгбэнг': 1,
#           'дорого': 4,
#           'охуенно': 3,
#           'есто': 1,
#           'спрятать': 13,
#           'специфический': 1,
#           'запах': 15,
#           'влага': 2,
#           'пакет': 1,
#           'испаряться': 1,
#           'моментально': 1,
#           'попадание': 1,
#           'воздух': 2,
#           'целое': 14,
#           'рабочий': 7,
#           'снятой': 21,
#           'бомба': 11,
#           'брать': 85,
#           'непервый': 7,
#           'довольный': 9,
#           'слабоватый': 4,
#           'upd': 1,
#           'неслабый': 1,
#           'действовать': 1,
#           'мягко': 4,
#           'приятный': 13,
#           'стим': 2,
#           'перегиб': 1,
#           'сильный': 6,
#           'танец': 1,
#           'челюсть': 2,
#           'шоп': 15,
#           'адекватный': 5,
#           'ответливый': 1,
#           'идти': 22,
#           'онлайн': 1,
#           'работа': 25,
#           'рекомендовать': 14,
#           'смело': 3,
#           'выслушать': 2,
#           'адрес': 18,
#           'уровнеобращаться': 1,
#           'условие': 3,
#           'достойный': 4,
#           'вкус': 4,
#           'подумать': 14,
#           'наебаловый': 2,
#           'дорога': 11,
#           'распидорасить': 1,
#           'конкретно': 8,
#           'красава': 8,
#           'такой': 38,
#           'чёткий': 10,
#           'нигде': 2,
#           'невидеть': 15,
#           'далековато': 1,
#           'пункт': 2,
#           'балл': 7,
#           'обязательно': 6,
#           'заглянуть': 4,
#           'нераз': 6,
#           'удача': 12,
#           'возникнуть': 12,
#           'трудность': 2,
#           'пойти': 17,
#           'уступка': 4,
#           'стафа': 47,
#           'крайнедолгий': 1,
#           'диспут': 84,
#           'результат': 9,
#           'прислать': 6,
#           'решение': 19,
#           'норма': 26,
#           '10упаковка': 1,
#           'гуд': 12,
#           'левый': 3,
#           'право': 1,
#           'перепутать': 2,
#           'вроде': 8,
#           'лихний': 1,
#           'найтись': 6,
#           'интересный': 3,
#           '7': 6,
#           'изз': 10,
#           'малый': 1,
#           'заявить': 7,
#           'ровно': 18,
#           '5': 22,
#           'вместе': 3,
#           'жир': 1,
#           'топчик': 4,
#           'стать': 11,
#           '3': 51,
#           'видный': 4,
#           'разместить': 1,
#           'возле': 4,
#           'лодочный': 1,
#           'станция': 4,
#           'незакладывать': 1,
#           'куча': 9,
#           'человек': 6,
#           'ребёнок': 2,
#           'кладмена': 91,
#           'незачёт': 1,
#           'бляять': 2,
#           'чувакиия': 1,
#           'чумава': 1,
#           'самый': 27,
#           'строгий': 1,
#           'мерка': 1,
#           'камень': 7,
#           'твёрдый': 3,
#           'орех': 1,
#           'заходить': 7,
#           'домой': 3,
#           'нежечь': 2,
#           'противный': 1,
#           'цвет': 4,
#           'белоснежный': 4,
#           'большой': 20,
#           'крупный': 4,
#           'выгодный': 1,
#           'отдельный': 8,
#           'полочка': 1,
#           'разложить': 1,
#           'забор': 5,
#           'небывать': 3,
#           'магазиневсем': 1,
#           'высокий': 11,
#           'гидротест': 1,
#           'соответствовать': 9,
#           'решать': 13,
#           'польза': 9,
#           'клиент': 18,
#           'незнать': 13,
#           'толя': 7,
#           'сытый': 1,
#           'система': 1,
#           'контроль': 1,
#           'какаять': 1,
#           'наладить': 1,
#           'небодяжатый': 1,
#           'один': 32,
#           'слово': 19,
#           'надёжно': 9,
#           'запазуха': 1,
#           'х': 4,
#           'gang': 3,
#           'bang': 3,
#           'rulit': 1,
#           'ненайти': 38,
#           '50': 15,
#           'дать': 28,
#           'стараться': 3,
#           'определяться': 1,
#           'нев': 16,
#           'далее': 2,
#           'неплохо': 3,
#           'пацан': 6,
#           'тройка': 1,
#           'сожаление': 12,
#           'уладить': 2,
#           'непробовать': 10,
#           'амф': 3,
#           'конкретный': 2,
#           'недовес': 15,
#           'нестать': 12,
#           'открывать': 23,
#           'настроению': 1,
#           'дополнить': 14,
#           'нестанция': 1,
#           'подлипка': 1,
#           'дачный': 1,
#           'мытищи': 1,
#           'строитель': 2,
#           'район': 6,
#           'неверно': 2,
#           'погрешность': 3,
#           'зашкаливать': 1,
#           'обозначить': 1,
#           'город': 9,
#           'товар': 44,
#           'цена': 15,
#           'сойти': 3,
#           'непроверять': 1,
#           'неточный': 2,
#           'средний': 1,
#           'географический': 1,
#           'кретинизм': 1,
#           'находиться': 8,
#           'поиск': 19,
#           'изя': 10,
#           'небольшой': 13,
#           'огорчить': 3,
#           'разрешить': 1,
#           'ситуация': 8,
#           'несмочь': 8,
#           'впредь': 1,
#           'знать': 20,
#           'какой': 22,
#           'фото': 54,
#           'предоставлять': 1,
#           'случай': 11,
#           'поднять': 28,
#           'спс': 1,
#           'хворать': 1,
#           'настолько': 2,
#           'ждать': 20,
#           'пикник': 2,
#           '2': 45,
#           'метр': 20,
#           'свалить': 1,
#           'украсить': 1,
#           'вечер': 14,
#           'погулять': 2,
#           'пофоткать': 1,
#           'кинуть': 11,
#           'весы': 13,
#           '014': 1,
#           'грамм': 19,
#           'округлить': 1,
#           'минус': 14,
#           'звезда': 2,
#           'учёт': 2,
#           'небез': 1,
#           'локация': 15,
#           'забросить': 1,
#           'дом': 22,
#           'территория': 1,
#           'сперва': 1,
#           'стоять': 3,
#           'двое': 6,
#           'дикий': 2,
#           'алкодемон': 1,
#           'два': 3,
#           'собака': 5,
#           'тип': 7,
#           'подойти': 4,
#           'говно': 10,
#           'чекать': 1,
#           'железка': 1,
#           'начинать': 5,
#           'лестница': 3,
#           'железный': 3,
#           'угол': 3,
#           'подождать': 3,
#           '15': 8,
#           'часик': 5,
#           'круг': 1,
#           'необстоятельство': 1,
#           'сработать': 2,
#           '11': 2,
#           'плавный': 4,
#           'мягкий': 6,
#           'выраженный': 1,
#           'эффект': 17,
#           'нестарый': 1,
#           'тест': 1,
#           'кач': 20,
#           'недотягивать': 2,
#           'чтотня': 1,
#           'мурашка': 1,
#           'искра': 1,
#           'спать': 2,
#           'захотеться': 2,
#           'вцелое': 1,
#           'подпирать': 1,
#           'мягенький': 1,
#           'надеяться': 12,
#           'премиум': 3,
#           'оставлять': 9,
#           'желать': 12,
#           'сейчас': 5,
#           'планк': 1,
#           'снизиться': 1,
#           'хотеться': 13,
#           'ставить': 11,
#           '710': 3,
#           'респектища': 2,
#           'среднен': 1,
#           'вообщий': 11,
#           'подъём': 5,
#           'быстрый': 8,
#           'код': 9,
#           'верный': 3,
#           'нулевой': 3,
#           'сода': 1,
#           'пищевой': 1,
#           'наслать': 21,
#           'капнуть': 1,
#           'нашлипонадобиться': 1,
#           'минутыкладмен': 1,
#           'респектвсе': 1,
#           'отличноместо': 1,
#           'супербезлюдный': 1,
#           '7вернуться': 1,
#           'купончикспасибо': 1,
#           'магнит': 20,
#           'этаж': 8,
#           'внутри': 4,
#           'лифт': 7,
#           'неработать': 1,
#           'повозиться': 4,
#           'непробывать': 2,
#           'полукасание': 1,
#           'качественный': 10,
#           'несоник': 1,
#           'икс': 1,
#           'тянуть': 4,
#           'кладчик': 2,
#           'ошибиться': 2,
#           'координата': 25,
#           'разница': 2,
#           '500': 2,
#           'дерево': 12,
#           'оказаться': 20,
#           'вода': 9,
#           '6': 3,
#           'итого': 3,
#           '8': 5,
#           'прибыть': 1,
#           'корень': 1,
#           'необнаружила': 1,
#           'отказываться': 3,
#           'общаться': 2,
#           'ник': 2,
#           'вынуждать': 1,
#           'покупатель': 13,
#           'портить': 3,
#           'статистика': 1,
#           'уточнить': 2,
#           'кладо': 1,
#           'клиентоооиентированость': 1,
#           '0': 16,
#           'сутки': 22,
#           'сказать': 18,
#           'магазинен': 1,
#           'последной': 1,
#           'начать': 8,
#           'вести': 6,
#           'непонятно': 3,
#           'ради': 2,
#           'взять': 32,
#           'исползовать': 1,
#           'сожилёный': 1,
#           'пусто': 13,
#           'ребята': 41,
#           'безапасность': 1,
#           'несоветовать': 27,
#           'никакой': 13,
#           'небыть': 76,
#           'повестись': 1,
#           'остаться': 10,
#           'разочарование': 1,
#           'потратить': 8,
#           'монета': 1,
#           'плохой': 16,
#           'людный': 9,
#           'нерекомендовать': 18,
#           'нужный': 8,
#           'амфет': 1,
#           'дата': 1,
#           'гашить': 1,
#           'открыть': 16,
#           'заменеотказать': 1,
#           'сидывал': 1,
#           'найдёный': 1,
#           'говорить': 12,
#           'неий': 1,
#           'сильно': 6,
#           'сомневаться': 3,
#           'положить': 6,
#           'неделя': 10,
#           'переписка': 2,
#           'бестолк': 1,
#           'хотеть': 27,
#           'кот': 1,
#           'мешок': 1,
#           'заказывать': 6,
#           'полный': 18,
#           'чашка': 1,
#           'кофе': 1,
#           'рубить': 1,
#           'народ': 3,
#           'небрать': 17,
#           'фуфло': 1,
#           'тфу': 1,
#           'дубль': 1,
#           'пустышка': 2,
#           'неохоть': 2,
#           'заморачиваться': 2,
#           'крайний': 1,
#           'мера': 2,
#           'понравиться': 7,
#           'информация': 3,
#           'местонахождение': 1,
#           'первый': 22,
#           'палевной': 4,
#           'каждый': 3,
#           'камера': 10,
#           'пешеход': 1,
#           'почитать': 2,
#           'отзов': 2,
#           'думать': 32,
#           'пиз': 1,
#           'каков': 1,
#           'удивление': 4,
#           'непереть': 2,
#           'рейтинг': 5,
#           'невестись': 1,
#           'стаж': 1,
#           'проходить': 3,
#           'несмотря': 4,
#           'обвинить': 1,
#           'маленький': 6,
#           'заборчик': 1,
#           'снизу': 2,
#           'лес': 36,
#           'находить': 1,
#           'прикопа': 22,
#           'сесть': 1,
#           'телефон': 4,
#           'память': 1,
#           'извинить': 2,
#           'разочаровать': 5,
#           'ваш': 10,
#           'магазинебольша': 1,
#           'неприйти': 2,
#           'инф': 2,
#           'привыктак': 1,
#           'когдато': 1,
#           'считать': 4,
#           'тихий': 7,
#           'гавань': 1,
#           'воспоминание': 1,
#           'произошлоно': 1,
#           'последний': 16,
#           'сплошной': 1,
#           'причём': 6,
#           'лютый': 9,
#           'исполнение': 4,
#           'отъ': 1,
#           'минимальный': 2,
#           'мненичего': 2,
#           'ненадо': 5,
#           'возмещение': 1,
#           'ущерб': 1,
#           'либо': 13,
#           'бонус': 2,
#           'парень': 13,
#           'необеднеть': 2,
#           'потеря': 3,
#           'репутация': 2,
#           'тема': 3,
#           'таки': 3,
#           'важный': 2,
#           'поэтому': 13,
#           'единомышленник': 1,
#           'совет': 3,
#           'подстраховаться': 1,
#           '1местобыла': 1,
#           'кладмагнит': 1,
#           '2по': 1,
#           'факт': 7,
#           'снежный': 5,
#           '3курьер': 1,
#           'млесной': 1,
#           'ужасный': 8,
#           'проявление': 1,
#           '4стафа': 1,
#           'нестоить': 2,
#           '5магазин': 1,
#           'неклиентоориентировать': 1,
#           'подряд': 15,
#           'мег': 2,
#           'перекопать': 2,
#           'трактор': 1,
#           'специально': 3,
#           'неоткрыть': 1,
#           'оставить': 6,
#           'тупо': 5,
#           'метро': 5,
#           'умудриться': 1,
#           'поискать': 2,
#           'ублюдок': 2,
#           'отнять': 1,
#           'вместо': 12,
#           'бетонный': 1,
#           'каменюг': 1,
#           'похожий': 5,
#           'отколоть': 2,
#           'бордюр': 2,
#           'настаивать': 2,
#           'ложь': 1,
#           'неразбиваться': 1,
#           'муляж': 1,
#           'техподдержка': 1,
#           'бесполезный': 2,
#           'короче': 4,
#           'развести': 2,
#           'увы': 6,
#           'смысл': 14,
#           'оператор': 13,
#           'пожевать': 1,
#           'мозг': 2,
#           'пара': 6,
#           'день': 20,
#           'сторона': 15,
#           'выбрать': 8,
#           'модератор': 13,
#           'друг': 24,
#           'дважды': 3,
#           'магазинепроблема': 1,
#           'четыре': 1,
#           'столько': 3,
#           'терять': 2,
#           'нерв': 5,
#           'несоздавать': 1,
#           'отказаться': 5,
#           'забыть': 3,
#           'страшный': 1,
#           'сон': 3,
#           'отвратительный': 4,
#           'ужас': 4,
#           'нормальный': 13,
#           'ориентир': 5,
#           'тяжело': 2,
#           'перестать': 3,
#           'вызывать': 2,
#           'доверие': 1,
#           'уверять': 2,
#           'виноватый': 2,
#           'гадать': 1,
#           'повезти': 6,
#           'следующий': 9,
#           'ненайтись': 1,
#           'послать': 4,
#           'история': 3,
#           'прежде': 3,
#           'отсутствуетневернуться': 1,
#           'жилой': 5,
#           'массив': 1,
#           'середина': 1,
#           'поле': 2,
#           'поддон': 1,
#           'хрен': 2,
#           'дойти': 5,
#           'щиколотка': 1,
#           'дрянь': 1,
#           'класть': 19,
#           'пасть': 3,
#           'взрыв': 1,
#           'местность': 3,
#           'естественно': 3,
#           'оценка': 19,
#           'орджо': 1,
#           'взорвать': 5,
#           'грустно': 1,
#           '5050тр': 1,
#           'неудевительный': 1,
#           'ибо': 7,
#           'шлак': 1,
#           'аспирин': 1,
#           'помоему': 1,
#           'лутша': 1,
#           'переть': 8,
#           'топ': 25,
#           'непригласить': 1,
#           'неспасибо': 1,
#           'ходок': 1,
#           'рыба': 1,
#           'плач': 1,
#           'видеть': 3,
#           'не1': 1,
#           'угодный': 1,
#           'неамфетамин': 1,
#           'затевать': 1,
#           'эпопея': 1,
#           'подобный': 3,
#           'чистый': 6,
#           'развод': 1,
#           'невести': 1,
#           'тропа': 4,
#           'продраться': 1,
#           'бурелом': 2,
#           'навигатор': 4,
#           'напоминать': 1,
#           'неоткрывать': 3,
#           'поскольку': 2,
#           'понимать': 5,
#           'мой': 17,
#           'обязать': 1,
#           'молотый': 1,
#           'таблетка': 2,
#           'мешатьбабяжить': 1,
#           'есть': 2,
#           'предлагать': 9,
#           'кончить': 4,
#           'мазин': 1,
#           'квэст': 2,
#           'пискать': 1,
#           'зачётный': 1,
#           'поход': 6,
#           'федя': 1,
#           'неюзали': 1,
#           'понятие': 2,
#           'амфома': 1,
#           'непахнуть': 2,
#           'притсвый': 1,
#           'замечательный': 2,
#           'пришол': 1,
#           'увидеть': 11,
#           'победить': 2,
#           'ро': 1,
#           'вылечить': 1,
#           'лунтик': 1,
#           'луна': 1,
#           'упасть': 3,
#           'родиться': 1,
#           'прятать': 2,
#           'копилка': 1,
#           'ктоть': 4,
#           'лезита': 1,
#           'шол': 1,
#           'выпал': 1,
#           'штаны': 2,
#           'искать': 27,
#           'потерять': 4,
#           'гий': 1,
#           'вывалиться': 1,
#           'путь': 3,
#           'успокоиться': 1,
#           'огромный': 8,
#           'хочть': 1,
#           'поблагодарить': 1,
#           'загрузить': 1,
#           'неполучаться': 1,
#           'летний': 1,
#           'некто': 1,
#           'непомочь': 3,
#           'раз': 23,
#           'пятак': 1,
#           'отдать': 1,
#           'швыр': 1,
#           'тюмень': 1,
#           'связь': 10,
#           'зарека': 1,
#           'пустой': 18,
#           'зимний': 4,
#           'обращение': 1,
#           'предложить': 25,
#           'мнекупить': 1,
#           'блядь': 8,
#           'готовый': 1,
#           'перезаклад': 30,
#           'чмо': 3,
#           'съесть': 10,
#           'адресь': 1,
#           'дебил': 3,
#           'неуметь': 1,
#           'говориться': 5,
#           'прийти': 9,
#           'маловатоно': 1,
#           'радовать': 10,
#           'наход': 6,
#           'позиция': 14,
#           'оба': 3,
#           'подъезд': 9,
#           'самитак': 1,
#           'ахинея': 1,
#           'нести': 1,
#           'оправдание': 1,
#           'никто': 17,
#           'реально': 9,
#           'нога': 9,
#           'невидеться': 2,
#           'сервис': 10,
#           'отстойникака': 1,
#           'клиентооринтироанность': 1,
#           'проверить': 7,
#           'дятел': 1,
#           'делать': 25,
#           'команда': 7,
#           'ветер': 12,
#           'долбаести': 2,
#           'легко': 8,
#           'испортиться': 2,
#           'амфа': 2,
#           'острожный': 1,
#           'мурманск': 2,
#           'слать': 1,
#           'невнятный': 1,
#           'который': 15,
#           'давать': 5,
#           'вкой': 1,
#           'счёт': 3,
#           'глазок': 1,
#           'сосед': 2,
#           'красавчик': 11,
#           'дурень': 1,
#           'здравствуйте': 2,
#           'бюджетный': 1,
#           'кладменлюбитель': 1,
#           'дверной': 1,
#           'косяк': 6,
#           '4к': 2,
#           'ботспиритуалист': 1,
#           'поддержкидвое': 1,
#           'вызывающий': 1,
#           'сугробсудить': 1,
#           'разгар': 1,
#           'зимыть': 1,
#           'реал': 1,
#           'полностью': 4,
#           'растаять': 3,
#           'локацияс': 1,
#           'рассыпать': 2,
#           'проталина': 1,
#           'костёр': 2,
#           'продавать': 7,
#           'кладыпо': 1,
#           'общемести': 1,
#           'спустить': 1,
#           'денежный': 1,
#           'средство': 4,
#           'определённо': 3,
#           'обратить': 3,
#           'внимание': 9,
#           'гнездо': 1,
#           'гомосексуалист': 1,
#           'добрый': 11,
#           'фотокарточка': 1,
#           'пейзаж': 1,
#           '3к': 1,
#           'нетота': 2,
#           'мелочь': 1,
#           'сравнение': 2,
#           'насколько': 1,
#           'мёртвый': 1,
#           'ниочь': 1,
#           'заниматься': 2,
#           'кидалово': 5,
#           'пролёт': 1,
#           '12к': 2,
#           'компенсация': 5,
#           'мочь': 16,
#           'пихануть': 1,
#           'рубас': 1,
#           'глубокий': 5,
#           'кладмэн': 3,
#           'скорый': 2,
#           'приём': 1,
#           'непо': 3,
#           'причинемагазин': 1,
#           'поговороримнесоветовать': 1,
#           'небеспокоятсянеберит': 1,
#           'перекрёсток': 2,
#           'набережная': 1,
#           'остать': 1,
#           'несмотреть': 2,
#           'секунда': 6,
#           'премёрзлый': 1,
#           'накапать': 1,
#           'трава': 9,
#           'уверенность': 1,
#           'чтоть': 5,
#           'отпадать': 1,
#           'отреагировать': 1,
#           'ложный': 1,
#           'высказывание': 1,
#           'неставить': 1,
#           'говоно': 1,
#           'нольквест': 1,
#           'пиздец': 12,
#           'колено': 1,
#           'снег': 16,
#           'серединелесапервый': 1,
#           '6г': 1,
#           'скурить': 1,
#           'бошка': 8,
#           'вышка': 6,
#           'произвести': 1,
#           'мина': 3,
#           'подход': 4,
#           'конфликт': 1,
#           'молодец': 8,
#           'орёл': 1,
#           'гнездеспасибо': 1,
#           'ребяткак': 1,
#           'класс': 2,
#           'неподвезти': 1,
#           'любимый': 2,
#           'джек': 1,
#           'иной': 2,
#           'предложение': 3,
#           'приглянуться': 1,
#           'вариант': 4,
#           'посмотреть': 3,
#           'остановиться': 1,
#           'оформить': 3,
#           'магаза': 27,
#           'понять': 11,
#           'несвезти': 1,
#           '25': 2,
#           'час': 29,
#           'чм': 1,
#           'дождь': 4,
#           'простой': 6,
#           'избранный': 2,
#           'круто': 4,
#           'сделка': 7,
#           ...})

# %%
#берем max_words наиболее часто встречающихся токенов
#(создаем упорядоченные пары (слово, частота) в количестве max_words штук и берем первые элементы пар)
tokens_filtered_top = [pair[0] for pair in dist.most_common(max_words-1)]  # -1 - padding
len(tokens_filtered_top), tokens_filtered_top[:10]
# Out:
# (4426,
#  ['место',
#   'клад',
#   'магазин',
#   'ненаход',
#   'качество',
#   'касание',
#   'кладмена',
#   'хороший',
#   '10',
#   'брать'])

# %%
#словарь слово : индекс из tokens_filtered_top
vocabulary = {v: k for k, v in dict(enumerate(tokens_filtered_top,1)).items()}
vocabulary
# Out:
# {'место': 1,
#  'клад': 2,
#  'магазин': 3,
#  'ненаход': 4,
#  'качество': 5,
#  'касание': 6,
#  'кладмена': 7,
#  'хороший': 8,
#  '10': 9,
#  'брать': 10,
#  'диспут': 11,
#  'небыть': 12,
#  'найти': 13,
#  'забрать': 14,
#  'фото': 15,
#  'покупка': 16,
#  'проблема': 17,
#  '3': 18,
#  'деньга': 19,
#  'стафа': 20,
#  '101010': 21,
#  'вес': 22,
#  '2': 23,
#  'сделать': 24,
#  'товар': 25,
#  'квест': 26,
#  'стаффа': 27,
#  'ребята': 28,
#  'курьер': 29,
#  'такой': 30,
#  'ненайти': 31,
#  'описание': 32,
#  'купон': 33,
#  'лес': 34,
#  'сразу': 35,
#  'снять': 36,
#  'решить': 37,
#  'чётко': 38,
#  'быстро': 39,
#  'один': 40,
#  'взять': 41,
#  'думать': 42,
#  'отзыв': 43,
#  'итог': 44,
#  'вообще': 45,
#  'прийтись': 46,
#  'респект': 47,
#  'перезаклад': 48,
#  'данный': 49,
#  'час': 50,
#  'дать': 51,
#  'поднять': 52,
#  'км': 53,
#  'магаз': 54,
#  'самый': 55,
#  'несоветовать': 56,
#  'хотеть': 57,
#  'искать': 58,
#  'магаза': 59,
#  'норма': 60,
#  'работа': 61,
#  'координата': 62,
#  'топ': 63,
#  'предложить': 64,
#  'делать': 65,
#  'марка': 66,
#  'друг': 67,
#  'купить': 68,
#  'сюда': 69,
#  'советовать': 70,
#  'открывать': 71,
#  'раз': 72,
#  'встреча': 73,
#  'идти': 74,
#  '5': 75,
#  'какой': 76,
#  'дом': 77,
#  'сутки': 78,
#  'первый': 79,
#  'прикопа': 80,
#  'отличный': 81,
#  '1010': 82,
#  'фотка': 83,
#  'упаковка': 84,
#  'кура': 85,
#  'снятой': 86,
#  'наслать': 87,
#  'минута': 88,
#  'отлично': 89,
#  'большой': 90,
#  'знать': 91,
#  'ждать': 92,
#  'метр': 93,
#  'кач': 94,
#  'магнит': 95,
#  'оказаться': 96,
#  'день': 97,
#  '4': 98,
#  'решение': 99,
#  'слово': 100,
#  'поиск': 101,
#  'грамм': 102,
#  'класть': 103,
#  'оценка': 104,
#  'тайник': 105,
#  'адрес': 106,
#  'ровно': 107,
#  'клиент': 108,
#  'сказать': 109,
#  'нерекомендовать': 110,
#  'полный': 111,
#  'пустой': 112,
#  'скидка': 113,
#  'пушка': 114,
#  'вопрос': 115,
#  'добро': 116,
#  'супер': 117,
#  'общий': 118,
#  'заказ': 119,
#  'свой': 120,
#  'процветание': 121,
#  'пойти': 122,
#  'эффект': 123,
#  'небрать': 124,
#  'мой': 125,
#  'никто': 126,
#  'новый': 127,
#  'покупать': 128,
#  'рука': 129,
#  'выдать': 130,
#  'немочь': 131,
#  'нев': 132,
#  '0': 133,
#  'плохой': 134,
#  'открыть': 135,
#  'последний': 136,
#  'мочь': 137,
#  'снег': 138,
#  'земля': 139,
#  'точка': 140,
#  'стоить': 141,
#  'запах': 142,
#  'шоп': 143,
#  'невидеть': 144,
#  '50': 145,
#  'недовес': 146,
#  'цена': 147,
#  'локация': 148,
#  'подряд': 149,
#  'сторона': 150,
#  'который': 151,
#  'смотреть': 152,
#  'мука': 153,
#  'остальной': 154,
#  'целое': 155,
#  'рекомендовать': 156,
#  'подумать': 157,
#  'дополнить': 158,
#  'вечер': 159,
#  'минус': 160,
#  'смысл': 161,
#  'позиция': 162,
#  '1': 163,
#  'точно': 164,
#  'надёжный': 165,
#  'спрятать': 166,
#  'приятный': 167,
#  'решать': 168,
#  'незнать': 169,
#  'небольшой': 170,
#  'весы': 171,
#  'хотеться': 172,
#  'покупатель': 173,
#  'пусто': 174,
#  'никакой': 175,
#  'либо': 176,
#  'парень': 177,
#  'поэтому': 178,
#  'оператор': 179,
#  'модератор': 180,
#  'нормальный': 181,
#  'правда': 182,
#  'лежать': 183,
#  'приехать': 184,
#  'указать': 185,
#  'около': 186,
#  'огонь': 187,
#  'работать': 188,
#  'удача': 189,
#  'возникнуть': 190,
#  'гуд': 191,
#  'сожаление': 192,
#  'нестать': 193,
#  'надеяться': 194,
#  'желать': 195,
#  'дерево': 196,
#  'говорить': 197,
#  'вместо': 198,
#  'ветер': 199,
#  'пиздец': 200,
#  'дело': 201,
#  'отвечать': 202,
#  'получить': 203,
#  'ночью': 204,
#  'тк': 205,
#  'отписаться': 206,
#  'видно': 207,
#  'пройти': 208,
#  'написать': 209,
#  'приятно': 210,
#  'бомба': 211,
#  'дорога': 212,
#  'стать': 213,
#  'высокий': 214,
#  'случай': 215,
#  'кинуть': 216,
#  'ставить': 217,
#  'вообщий': 218,
#  'увидеть': 219,
#  'красавчик': 220,
#  'добрый': 221,
#  'понять': 222,
#  'площадка': 223,
#  'прям': 224,
#  'нечего': 225,
#  'зайти': 226,
#  'изолента': 227,
#  'администрация': 228,
#  'непойти': 229,
#  'отношение': 230,
#  'чайка': 231,
#  'трип': 232,
#  'три': 233,
#  'поддержка': 234,
#  'видимо': 235,
#  'опыт': 236,
#  'ответ': 237,
#  'чёткий': 238,
#  'изз': 239,
#  'непробовать': 240,
#  'изя': 241,
#  'говно': 242,
#  'качественный': 243,
#  'остаться': 244,
#  'неделя': 245,
#  'камера': 246,
#  'ваш': 247,
#  'связь': 248,
#  'съесть': 249,
#  'радовать': 250,
#  'сервис': 251,
#  'лёгкий': 252,
#  'второй': 253,
#  'плюс': 254,
#  'шкурный': 255,
#  'ноль': 256,
#  'больший': 257,
#  '30': 258,
#  'получиться': 259,
#  'попробовать': 260,
#  'старый': 261,
#  'держать': 262,
#  'еле': 263,
#  '100': 264,
#  'писать': 265,
#  'довольный': 266,
#  'результат': 267,
#  'куча': 268,
#  'соответствовать': 269,
#  'польза': 270,
#  'надёжно': 271,
#  'город': 272,
#  'оставлять': 273,
#  'код': 274,
#  'вода': 275,
#  'людный': 276,
#  'лютый': 277,
#  'следующий': 278,
#  'предлагать': 279,
#  'прийти': 280,
#  'подъезд': 281,
#  'реально': 282,
#  'нога': 283,
#  'внимание': 284,
#  'трава': 285,
#  'косание': 286,
#  'неочень': 287,
#  'поставить': 288,
#  'белый': 289,
#  'пак': 290,
#  'вход': 291,
#  'плохо': 292,
#  'нехотеть': 293,
#  'мир': 294,
#  'благо': 295,
#  'ответить': 296,
#  'ps': 297,
#  'цум': 298,
#  'количество': 299,
#  'пол': 300,
#  'успех': 301,
#  'ходить': 302,
#  'окно': 303,
#  'ровный': 304,
#  'забирать': 305,
#  'очередной': 306,
#  'нехватать': 307,
#  'крутой': 308,
#  'вернуться': 309,
#  'конкретно': 310,
#  'красава': 311,
#  'вроде': 312,
#  'отдельный': 313,
#  'находиться': 314,
#  'ситуация': 315,
#  'несмочь': 316,
#  '15': 317,
#  'быстрый': 318,
#  'этаж': 319,
#  'начать': 320,
#  'потратить': 321,
#  'нужный': 322,
#  'ужасный': 323,
#  'выбрать': 324,
#  'переть': 325,
#  'огромный': 326,
#  'блядь': 327,
#  'легко': 328,
#  'бошка': 329,
#  'молодец': 330,
#  'улица': 331,
#  'уровень': 332,
#  'хз': 333,
#  'нахуй': 334,
#  'вид': 335,
#  'минёр': 336,
#  'единственный': 337,
#  'прошлый': 338,
#  'провести': 339,
#  'сошкурить': 340,
#  'ночь': 341,
#  'любой': 342,
#  'кача': 343,
#  'меф': 344,
#  'купончик': 345,
#  'прогулка': 346,
#  'момент': 347,
#  'попасть': 348,
#  'указанный': 349,
#  'глаз': 350,
#  'сидеть': 351,
#  'рабочий': 352,
#  'непервый': 353,
#  'балл': 354,
#  'заявить': 355,
#  'камень': 356,
#  'заходить': 357,
#  'толя': 358,
#  'тип': 359,
#  'лифт': 360,
#  'понравиться': 361,
#  'тихий': 362,
#  'факт': 363,
#  'ибо': 364,
#  'проверить': 365,
#  'команда': 366,
#  'продавать': 367,
#  'сделка': 368,
#  'наш': 369,
#  'неповезти': 370,
#  'шишка': 371,
#  'хуйня': 372,
#  'скорее': 373,
#  'другой': 374,
#  'мол': 375,
#  'пусть': 376,
#  'продавец': 377,
#  'закрыть': 378,
#  'рулетка': 379,
#  'точный': 380,
#  'никак': 381,
#  'сложно': 382,
#  'уйти': 383,
#  'случайно': 384,
#  'явно': 385,
#  'чёрный': 386,
#  'должный': 387,
#  'порадовать': 388,
#  'мокрый': 389,
#  'корд': 390,
#  'ебеня': 391,
#  'душа': 392,
#  'нету': 393,
#  'фен': 394,
#  'весь': 395,
#  'гидра': 396,
#  'просьба': 397,
#  'сумма': 398,
#  'судить': 399,
#  'сильный': 400,
#  'обязательно': 401,
#  'нераз': 402,
#  'прислать': 403,
#  'найтись': 404,
#  '7': 405,
#  'человек': 406,
#  'пацан': 407,
#  'район': 408,
#  'двое': 409,
#  'мягкий': 410,
#  'вести': 411,
#  'сильно': 412,
#  'положить': 413,
#  'заказывать': 414,
#  'маленький': 415,
#  'причём': 416,
#  'оставить': 417,
#  'увы': 418,
#  'пара': 419,
#  'повезти': 420,
#  'чистый': 421,
#  'поход': 422,
#  'наход': 423,
#  'косяк': 424,
#  'секунда': 425,
#  'вышка': 426,
#  'простой': 427,
#  'забег': 428,
#  '10ка': 429,
#  'честно': 430,
#  'испортить': 431,
#  'оперативно': 432,
#  'хватить': 433,
#  'хуй': 434,
#  'улёт': 435,
#  'валяться': 436,
#  'падик': 437,
#  'странный': 438,
#  'принять': 439,
#  'кайф': 440,
#  'неполучить': 441,
#  'голова': 442,
#  'спустя': 443,
#  'свежий': 444,
#  '20': 445,
#  'перерыть': 446,
#  'ехать': 447,
#  'скоро': 448,
#  'жопа': 449,
#  'выйти': 450,
#  'выходить': 451,
#  'порядок': 452,
#  'долгий': 453,
#  'повод': 454,
#  'машина': 455,
#  'помочь': 456,
#  '010': 457,
#  'приход': 458,
#  'аккаунт': 459,
#  'неделать': 460,
#  'ненаслать': 461,
#  'нос': 462,
#  'прямо': 463,
#  'просить': 464,
#  'попросить': 465,
#  'равно': 466,
#  'сообщение': 467,
#  'цао': 468,
#  'правило': 469,
#  'претензия': 470,
#  'максимально': 471,
#  'пытаться': 472,
#  'закинуть': 473,
#  'курс': 474,
#  'оч': 475,
#  'нить': 476,
#  'ход': 477,
#  'полиция': 478,
#  'адекватный': 479,
#  'забор': 480,
#  'собака': 481,
#  'начинать': 482,
#  'часик': 483,
#  'сейчас': 484,
#  'подъём': 485,
#  '8': 486,
#  'рейтинг': 487,
#  'разочаровать': 488,
#  'ненадо': 489,
#  'снежный': 490,
#  'тупо': 491,
#  'метро': 492,
#  'похожий': 493,
#  'нерв': 494,
#  'отказаться': 495,
#  'ориентир': 496,
#  'жилой': 497,
#  'дойти': 498,
#  'взорвать': 499,
#  'понимать': 500,
#  'говориться': 501,
#  'давать': 502,
#  'кидалово': 503,
#  'компенсация': 504,
#  'глубокий': 505,
#  'чтоть': 506,
#  'благодарочка': 507,
#  'закладка': 508,
#  'несомневаться': 509,
#  'хер': 510,
#  'пресс': 511,
#  'след': 512,
#  'лично': 513,
#  'быть': 514,
#  'пробивать': 515,
#  'пробовать': 516,
#  '40': 517,
#  'снимать': 518,
#  'иза': 519,
#  'впервые': 520,
#  'пох': 521,
#  'куст': 522,
#  'дерьмо': 523,
#  'нихуй': 524,
#  'компромисс': 525,
#  'засунуть': 526,
#  'пидор': 527,
#  'прогуляться': 528,
#  'обратный': 529,
#  'красавец': 530,
#  'несказать': 531,
#  'лсд': 532,
#  'интересно': 533,
#  'попытка': 534,
#  'доступность': 535,
#  'примерно': 536,
#  'неплохой': 537,
#  'неприйтись': 538,
#  'кусок': 539,
#  'настроение': 540,
#  'ездить': 541,
#  '170': 542,
#  'жаль': 543,
#  'пизда': 544,
#  'отметить': 545,
#  'случиться': 546,
#  'перевес': 547,
#  'обнять': 548,
#  'желание': 549,
#  'играть': 550,
#  'птичка': 551,
#  'выкинуть': 552,
#  'слабый': 553,
#  'накуривать': 554,
#  'жесть': 555,
#  'глубина': 556,
#  'рыть': 557,
#  'благодарить': 558,
#  'че': 559,
#  'недать': 560,
#  'шив': 561,
#  'вежливый': 562,
#  '2гр': 563,
#  'они': 564,
#  'фотография': 565,
#  'развернуть': 566,
#  'пидарас': 567,
#  'дорого': 568,
#  'слабоватый': 569,
#  'мягко': 570,
#  'достойный': 571,
#  'вкус': 572,
#  'заглянуть': 573,
#  'уступка': 574,
#  'топчик': 575,
#  'видный': 576,
#  'возле': 577,
#  'станция': 578,
#  'цвет': 579,
#  'белоснежный': 580,
#  'крупный': 581,
#  'х': 582,
#  'подойти': 583,
#  'плавный': 584,
#  'внутри': 585,
#  'повозиться': 586,
#  'тянуть': 587,
#  'палевной': 588,
#  'удивление': 589,
#  'несмотря': 590,
#  'телефон': 591,
#  'считать': 592,
#  'исполнение': 593,
#  'короче': 594,
#  'отвратительный': 595,
#  'ужас': 596,
#  'послать': 597,
#  'тропа': 598,
#  'навигатор': 599,
#  'кончить': 600,
#  'ктоть': 601,
#  'потерять': 602,
#  'зимний': 603,
#  'полностью': 604,
#  'средство': 605,
#  'подход': 606,
#  'вариант': 607,
#  'дождь': 608,
#  'круто': 609,
#  'накурить': 610,
#  'привет': 611,
#  'благодарность': 612,
#  'однозначно': 613,
#  'касаха': 614,
#  'чай': 615,
#  'пахнуть': 616,
#  'ошибка': 617,
#  'половина': 618,
#  'топовый': 619,
#  'отзывчивый': 620,
#  'приобрести': 621,
#  'осторожный': 622,
#  'толь': 623,
#  'чудом': 624,
#  'сухой': 625,
#  '1г': 626,
#  'домофон': 627,
#  'отказать': 628,
#  'осадка': 629,
#  'достать': 630,
#  'постоянный': 631,
#  'дырка': 632,
#  'ёбаный': 633,
#  'недумать': 634,
#  'кидать': 635,
#  'сугроб': 636,
#  'труба': 637,
#  'магазиней': 638,
#  'выиграть': 639,
#  'убить': 640,
#  'отправить': 641,
#  'пешком': 642,
#  'закапывать': 643,
#  'акка': 644,
#  'бабка': 645,
#  'сложный': 646,
#  'рисковать': 647,
#  'идеальный': 648,
#  'сука': 649,
#  'чуткий': 650,
#  'шикарный': 651,
#  'указывать': 652,
#  'нарекание': 653,
#  'вещество': 654,
#  'заложить': 655,
#  'добавить': 656,
#  'ожидание': 657,
#  'уверенный': 658,
#  'кстати': 659,
#  'возможно': 660,
#  'неподойти': 661,
#  'рад': 662,
#  'аккуратный': 663,
#  'скинуть': 664,
#  'снятие': 665,
#  'продукт': 666,
#  'выходной': 667,
#  'сайт': 668,
#  'стена': 669,
#  'несколько': 670,
#  'прочитать': 671,
#  'бывать': 672,
#  'заказать': 673,
#  'проходной': 674,
#  'читать': 675,
#  'положительный': 676,
#  'зачёт': 677,
#  'понятный': 678,
#  'разный': 679,
#  '12': 680,
#  'частый': 681,
#  'главное': 682,
#  'приходить': 683,
#  'являться': 684,
#  'удобный': 685,
#  'порошок': 686,
#  'нерешать': 687,
#  'невернуться': 688,
#  'фольга': 689,
#  'приезжать': 690,
#  '05': 691,
#  'неадекватный': 692,
#  'копать': 693,
#  'просматриваться': 694,
#  'ловить': 695,
#  'мусор': 696,
#  'марочка': 697,
#  'мефедрон': 698,
#  'слой': 699,
#  'параллельный': 700,
#  'биток': 701,
#  'получать': 702,
#  'течение': 703,
#  'понятно': 704,
#  'сверху': 705,
#  'заклад': 706,
#  'проехать': 707,
#  'непонимать': 708,
#  'живописный': 709,
#  'охуенно': 710,
#  'смело': 711,
#  'условие': 712,
#  'левый': 713,
#  'интересный': 714,
#  'вместе': 715,
#  'твёрдый': 716,
#  'домой': 717,
#  'небывать': 718,
#  'gang': 719,
#  'bang': 720,
#  'стараться': 721,
#  'неплохо': 722,
#  'амф': 723,
#  'погрешность': 724,
#  'сойти': 725,
#  'огорчить': 726,
#  'стоять': 727,
#  'два': 728,
#  'лестница': 729,
#  'железный': 730,
#  'угол': 731,
#  'подождать': 732,
#  'премиум': 733,
#  '710': 734,
#  'верный': 735,
#  'нулевой': 736,
#  '6': 737,
#  'итого': 738,
#  'отказываться': 739,
#  'портить': 740,
#  'непонятно': 741,
#  'сомневаться': 742,
#  'народ': 743,
#  'информация': 744,
#  'каждый': 745,
#  'проходить': 746,
#  'потеря': 747,
#  'тема': 748,
#  'таки': 749,
#  'совет': 750,
#  'специально': 751,
#  'дважды': 752,
#  'столько': 753,
#  'забыть': 754,
#  'сон': 755,
#  'перестать': 756,
#  'история': 757,
#  'прежде': 758,
#  'пасть': 759,
#  'местность': 760,
#  'естественно': 761,
#  'видеть': 762,
#  'подобный': 763,
#  'неоткрывать': 764,
#  'упасть': 765,
#  'путь': 766,
#  'непомочь': 767,
#  'чмо': 768,
#  'дебил': 769,
#  'оба': 770,
#  'счёт': 771,
#  'растаять': 772,
#  'определённо': 773,
#  'обратить': 774,
#  'кладмэн': 775,
#  'непо': 776,
#  'мина': 777,
#  'предложение': 778,
#  'посмотреть': 779,
#  'оформить': 780,
#  'правдо': 781,
#  'кировский': 782,
#  'вкусный': 783,
#  'решиться': 784,
#  'братец': 785,
#  'опробовать': 786,
#  'появиться': 787,
#  'поклон': 788,
#  '9': 789,
#  '5г': 790,
#  'руб': 791,
#  'план': 792,
#  'причина': 793,
#  'выдавать': 794,
#  'смочь': 795,
#  'весьма': 796,
#  'слава': 797,
#  'двор': 798,
#  'бомбовый': 799,
#  'расход': 800,
#  'както': 801,
#  'гость': 802,
#  'снизить': 803,
#  '02': 804,
#  'учитывать': 805,
#  '2г': 806,
#  'неменее': 807,
#  'объяснить': 808,
#  'заебись': 809,
#  'помощь': 810,
#  '00': 811,
#  'обычный': 812,
#  'дальнейший': 813,
#  'ветка': 814,
#  'разбираться': 815,
#  'уехать': 816,
#  'оторвать': 817,
#  'съём': 818,
#  'поехать': 819,
#  'квадрат': 820,
#  'страшно': 821,
#  'ожидать': 822,
#  'повторный': 823,
#  'заметить': 824,
#  'бро': 825,
#  'описать': 826,
#  'вернуть': 827,
#  'негатив': 828,
#  'невозможно': 829,
#  'труд': 830,
#  'незайти': 831,
#  'ак47': 832,
#  'гений': 833,
#  'постоянно': 834,
#  'тварь': 835,
#  'саппорт': 836,
#  'дорогой': 837,
#  'целый': 838,
#  'непожалеть': 839,
#  'непоехать': 840,
#  'бумага': 841,
#  'сыграть': 842,
#  'висеть': 843,
#  'любить': 844,
#  'побочка': 845,
#  'палец': 846,
#  'достаточно': 847,
#  'классный': 848,
#  'полёт': 849,
#  'мнепоказаться': 850,
#  'казус': 851,
#  'уважаемый': 852,
#  'выяснить': 853,
#  'шаговый': 854,
#  'упаковать': 855,
#  'намного': 856,
#  'непроходимый': 857,
#  'неоказаться': 858,
#  'картон': 859,
#  'нето': 860,
#  'листва': 861,
#  'риск': 862,
#  'совершенно': 863,
#  'недавать': 864,
#  'попытаться': 865,
#  'обратиться': 866,
#  'безлюдный': 867,
#  'совершить': 868,
#  'непокупать': 869,
#  'тропинка': 870,
#  'обидно': 871,
#  'попасться': 872,
#  'связываться': 873,
#  'замена': 874,
#  'несобираться': 875,
#  'благодаря': 876,
#  'зип': 877,
#  '14': 878,
#  'младенец': 879,
#  'база': 880,
#  'профи': 881,
#  'екб': 882,
#  'взгляд': 883,
#  'шпек': 884,
#  'время': 885,
#  'природа': 886,
#  'приветствовать': 887,
#  'очередь': 888,
#  'мент': 889,
#  'толика': 890,
#  'утро': 891,
#  'спокойный': 892,
#  'покемон': 893,
#  'жирный': 894,
#  'высота': 895,
#  'скорость': 896,
#  'ценакачество': 897,
#  'рынок': 898,
#  'московский': 899,
#  'эйфория': 900,
#  'нео': 901,
#  'неидти': 902,
#  'заплатить': 903,
#  'ахуенно': 904,
#  'напротив': 905,
#  'др': 906,
#  'удаться': 907,
#  'подавиться': 908,
#  'пролетарский': 909,
#  'суппорт': 910,
#  'проходимый': 911,
#  'травка': 912,
#  'ура': 913,
#  'шиха': 914,
#  'обнаружить': 915,
#  'курить': 916,
#  'аптека': 917,
#  'жечь': 918,
#  'бал': 919,
#  'аж': 920,
#  'непресс': 921,
#  'воу': 922,
#  'близкий': 923,
#  'успешный': 924,
#  'болото': 925,
#  'удовольствие': 926,
#  'несошкурить': 927,
#  'чаевой': 928,
#  'бог': 929,
#  'гр': 930,
#  'ценник': 931,
#  'промах': 932,
#  'новокосино': 933,
#  'остановка': 934,
#  'показать': 935,
#  'расстояние': 936,
#  'неотвечаять': 937,
#  'иметь': 938,
#  'бля': 939,
#  'центр': 940,
#  'выбирать': 941,
#  'правильно': 942,
#  'зарыть': 943,
#  'конченый': 944,
#  'завтра': 945,
#  'опытный': 946,
#  'красивый': 947,
#  'грязный': 948,
#  'збс': 949,
#  'наступать': 950,
#  'дно': 951,
#  'глубоко': 952,
#  'общение': 953,
#  'ненужный': 954,
#  'детский': 955,
#  'отдавать': 956,
#  'прекрасный': 957,
#  'уважение': 958,
#  'кристалл': 959,
#  'копейка': 960,
#  'мазать': 961,
#  'вонять': 962,
#  'кристаллический': 963,
#  'пудра': 964,
#  'диск': 965,
#  'го': 966,
#  'комиссия': 967,
#  'тд': 968,
#  'купонить': 969,
#  '150': 970,
#  'еда': 971,
#  'кароч': 972,
#  'свет': 973,
#  'фонарик': 974,
#  'добротный': 975,
#  'итак': 976,
#  'отписать': 977,
#  '1000': 978,
#  'рубль': 979,
#  'неудачный': 980,
#  'удивляться': 981,
#  'незря': 982,
#  'комар': 983,
#  'влага': 984,
#  'воздух': 985,
#  'стим': 986,
#  'челюсть': 987,
#  'выслушать': 988,
#  'наебаловый': 989,
#  'нигде': 990,
#  'пункт': 991,
#  'трудность': 992,
#  'перепутать': 993,
#  'ребёнок': 994,
#  'бляять': 995,
#  'нежечь': 996,
#  'далее': 997,
#  'уладить': 998,
#  'конкретный': 999,
#  'строитель': 1000,
#  ...}

# %%
#преобразование текста в последовательность
def text_to_sequence(text, maxlen):
    result = []
    tokens = word_tokenize(text.lower())  #токенизация
    tokens_filtered = [word for word in tokens if word.isalnum()] #фильтруем (только буквы и цифры)
    for word in tokens_filtered:
        if word in vocabulary:
            result.append(vocabulary[word]) #если слово в топе токенов, то добавляем его индекс в результат

    padding = [0] * (maxlen-len(result)) #нули дополняющие до maxlen
    return result[-maxlen:] + padding

# %%
x_train = np.asarray([text_to_sequence(text, max_len) for text in train["content"]], dtype=np.int32)
x_valid = np.asarray([text_to_sequence(text, max_len) for text in validate["content"]], dtype=np.int32)
x_test = np.asarray([text_to_sequence(text, max_len) for text in test["content"]], dtype=np.int32)

x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((840, 10), (180, 10), (180, 10))

# %%
#данные после подготовки к обучению
torch.from_numpy(x_train[0])
# Out:
# tensor([ 699, 1557,  471,  562,  234,  345,    3, 1558,  115,   82],
#        dtype=torch.int32)

# %%
x_train[1]
# Out:
# array([ 21,   8, 346,   8, 394, 127,  73,   0,   0,   0], dtype=int32)

# %%
from torch.utils.data import DataLoader, Dataset
import torch


class DataWrapper(Dataset):
    def __init__(self, data, target, transform=None):
        self.data = torch.from_numpy(data).long()
        self.target = torch.from_numpy(target).long()
        self.transform = transform
        
    def __getitem__(self, index):
        x = self.data[index]
        y = self.target[index]
        
        if self.transform:
            x = self.transform(x)
            
        return x, y
    
    def __len__(self):
        return len(self.data)

# %%
df_train
# Out:
#                                                 content  sentiment
# 0     Был ненаход (клад похоронили под слоем бетона)...          1
# 1     10/10/10 хорошая прогулка, за хорошим феном. Д...          1
# 2     Дома,соточки по всем параметрам,спасибо всей к...          1
# 3              Все супер, квест момент, Стафф как надо!          1
# 4                                            всё хорошо          1
# ...                                                 ...        ...
# 1195  Не наход. Магазин сказал ждём минёра, тот так ...          0
# 1196  НИ ОДНОГО НАХОДА. 3 РАЗА ВСЕ МИМО. оно и неуди...          0
# 1197  Ненаход, в неочень долгом диспуте магазин и кл...          0
# 1198  Пиздец!!! Это мало говоря. Канавинский р-он, з...          0
# 1199  Был ненаход, магаз норм, но всё возможно как о...          0
#
# [1200 rows x 2 columns]

# %%
train_dataset = DataWrapper(x_train, train['sentiment'].values)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = DataWrapper(x_valid, validate['sentiment'].values)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)

# %%
for x, l in train_loader:
    print(x.shape, x[0])
    print(l.shape, l[0])
    break
# Out:
# torch.Size([512, 10]) tensor([ 319,  585,  360,  360, 1706,   46,  586,   44,   14, 1015])
# torch.Size([512]) tensor(1)

# %%
#LSTM
class LSTMFixedLen(nn.Module):
    def __init__(self, vocab_size, embedding_dim=128, hidden_dim=128, use_last=True):
        super().__init__()
        self.use_last = use_last
        self.embeddings = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=2, batch_first=True)
        self.linear = nn.Linear(hidden_dim, 1)
        self.dropout = nn.Dropout(0.2)
        
    def forward(self, x):
        x = self.embeddings(x)
        x = self.dropout(x)

        lstm_out, ht = self.lstm(x) 
        # lstm_out: тензор с выходными фичами с последнего слоя для каждого t #(B, L, Hout)
        # h_t: тензор с последними скрытыми состояниями по слоям  #(num_layers, B, Hout)

        if self.use_last:
            last_tensor = lstm_out[:,-1,:]  #(B, Hout) тензор с последней строкой из каждого батча
        else:
            # use mean
            last_tensor = torch.mean(lstm_out[:,:], dim=1)  #(B, Hout) тензор со средним арифметическим столбцов по каждому батчу
    
        out = self.linear(last_tensor)
        
        return torch.sigmoid(out)

# %%
#инициализация модели
model_lstm = LSTMFixedLen(max_words, 128, 128, use_last=False)
print(model_lstm)
print("Parameters:", sum([param.nelement() for param in model_lstm.parameters()]))
# Out:
# LSTMFixedLen(
#   (embeddings): Embedding(20000, 128, padding_idx=0)
#   (lstm): LSTM(128, 128, num_layers=2, batch_first=True)
#   (linear): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# Parameters: 2824321

# %%
#компиляция модели
optimizer = torch.optim.Adam(model_lstm.parameters(), lr=0.001)
criterion = nn.BCELoss()

# %%
import torchmetrics

# %%
# %%time

#обучение модели
model_lstm.train()

train_loss_history = []
valid_loss_history = []

train_acc_history_lstm = []
valid_acc_history_lstm = []

train_acc = torchmetrics.Accuracy()
test_acc = torchmetrics.Accuracy()

for epoch in range(epochs):  
    model_lstm.train()
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data[0], data[1]

        # обнуляем градиент
        optimizer.zero_grad()
        outputs = model_lstm(inputs)
        loss = criterion(outputs, labels.float().view(-1, 1))
        loss.backward()
        optimizer.step()

        # подсчет ошибки на обучении
        loss = loss.item()
        
        # подсчет метрики на обучении
        train_acc(outputs.squeeze(), labels)
        
    # выводим статистику о процессе обучения
    model_lstm.eval()
    
    print(f'Epoch [{epoch + 1}/{epochs}]. ' \
            f'Step [{i + 1}/{len(train_loader)}]. ' \
            f'Loss: {loss:.3f}. ' \
            f'Acc: {train_acc.compute().item():.3f}', end='. ')

    train_loss_history.append(loss)
    train_acc_history_lstm.append(train_acc.compute().item())
    train_acc.reset()

    
    # выводим статистику на тестовых данных
    for j, data in enumerate(val_loader):
        test_labels = data[1]
        test_outputs = model_lstm(data[0])
        
        # подсчет ошибки на тесте
        test_loss = criterion(test_outputs, test_labels.float().view(-1, 1))
        
        # подсчет метрики на тесте
        test_acc(test_outputs.squeeze(), test_labels)

    print(f'Test loss: {test_loss:.3f}. Test acc: {test_acc.compute().item():.3f}')
    valid_loss_history.append(test_loss.item())
    valid_acc_history_lstm.append(test_acc.compute().item())
    test_acc.reset()
    
print('Training is finished!')
# Out:
# Epoch [1/10]. Step [2/2]. Loss: 0.672. Acc: 0.583. Test loss: 0.680. Test acc: 0.583
# Epoch [2/10]. Step [2/2]. Loss: 0.660. Acc: 0.657. Test loss: 0.660. Test acc: 0.633
# Epoch [3/10]. Step [2/2]. Loss: 0.629. Acc: 0.706. Test loss: 0.627. Test acc: 0.678
# Epoch [4/10]. Step [2/2]. Loss: 0.589. Acc: 0.751. Test loss: 0.585. Test acc: 0.694
# Epoch [5/10]. Step [2/2]. Loss: 0.528. Acc: 0.758. Test loss: 0.547. Test acc: 0.706
# Epoch [6/10]. Step [2/2]. Loss: 0.525. Acc: 0.770. Test loss: 0.533. Test acc: 0.722
# Epoch [7/10]. Step [2/2]. Loss: 0.460. Acc: 0.770. Test loss: 0.539. Test acc: 0.744
# Epoch [8/10]. Step [2/2]. Loss: 0.415. Acc: 0.807. Test loss: 0.559. Test acc: 0.744
# Epoch [9/10]. Step [2/2]. Loss: 0.428. Acc: 0.808. Test loss: 0.573. Test acc: 0.744
# Epoch [10/10]. Step [2/2]. Loss: 0.418. Acc: 0.819. Test loss: 0.568. Test acc: 0.739
# Training is finished!
# CPU times: user 5.55 s, sys: 79.6 ms, total: 5.63 s
# Wall time: 9.03 s

# %%
#визуализации функции потерь
plt.title('Loss history')
plt.grid(True)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(train_loss_history, label='train')
plt.plot(valid_loss_history, label='valid')
plt.legend()

# %%
#визуализации метрики
plt.title('Accuracy history')
plt.grid(True)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(train_acc_history_lstm, label='train')
plt.plot(valid_acc_history_lstm, label='valid')
plt.legend()

# %%
#GRU
class GRUFixedLen(nn.Module):
    def __init__(self, vocab_size, embedding_dim=128, hidden_dim=128, use_last=True):
        super().__init__()
        self.use_last = use_last
        self.embeddings = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.gru = nn.GRU(embedding_dim, hidden_dim, num_layers=2, batch_first=True)
        self.linear = nn.Linear(hidden_dim, 1)
        self.dropout = nn.Dropout(0.2)
        
    def forward(self, x):
        x = self.embeddings(x)
        x = self.dropout(x)

        gru_out, ht = self.gru(x) 
        # gru_out: тензор с выходными фичами с последнего слоя для каждого t #(B, L, Hout)
        # h_t: тензор с последними скрытыми состояниями по слоям  #(num_layers, B, Hout)

        if self.use_last:
            last_tensor = gru_out[:,-1,:]  #(B, Hout) тензор с последней строкой из каждого батча
        else:
            # use mean
            last_tensor = torch.mean(gru_out[:,:], dim=1)  #(B, Hout) тензор со средним арифметическим столбцов по каждому батчу
    
        out = self.linear(last_tensor)
        
        return torch.sigmoid(out)

# %%
#инициализация модели
model_gru = GRUFixedLen(max_words, 128, 128, use_last=False)
print(model_gru)
print("Parameters:", sum([param.nelement() for param in model_gru.parameters()]))

# %%
#компиляция модели
optimizer = torch.optim.Adam(model_gru.parameters(), lr=0.001)
criterion = nn.BCELoss()

# %%
# %%time

#обучение модели
model_gru.train()

train_loss_history = []
valid_loss_history = []

train_acc_history_gru = []
valid_acc_history_gru = []

train_acc = torchmetrics.Accuracy()
test_acc = torchmetrics.Accuracy()

for epoch in range(epochs):  
    model_gru.train()
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data[0], data[1]

        # обнуляем градиент
        optimizer.zero_grad()
        outputs = model_gru(inputs)
        loss = criterion(outputs, labels.float().view(-1, 1))
        loss.backward()
        optimizer.step()

        # подсчет ошибки на обучении
        loss = loss.item()
        
        # подсчет метрики на обучении
        train_acc(outputs.squeeze(), labels)
        
    # выводим статистику о процессе обучения
    model_gru.eval()
    
    print(f'Epoch [{epoch + 1}/{epochs}]. ' \
            f'Step [{i + 1}/{len(train_loader)}]. ' \
            f'Loss: {loss:.3f}. ' \
            f'Acc: {train_acc.compute().item():.3f}', end='. ')

    train_loss_history.append(loss)
    train_acc_history_gru.append(train_acc.compute().item())
    train_acc.reset()
    

    # выводим статистику на тестовых данных

    for j, data in enumerate(val_loader):
        test_labels = data[1]
        test_outputs = model_gru(data[0])
        
        # подсчет ошибки на тесте
        test_loss = criterion(test_outputs, test_labels.float().view(-1, 1))
        
        # подсчет метрики на тесте
        test_acc(test_outputs.squeeze(), test_labels)
    
    print(f'Test loss: {test_loss:.3f}. Test acc: {test_acc.compute().item():.3f}')
    valid_loss_history.append(test_loss.item())
    valid_acc_history_gru.append(test_acc.compute().item())
    test_acc.reset()
    
print('Training is finished!')
# Out:
# Epoch [1/10]. Step [2/2]. Loss: 0.672. Acc: 0.617. Test loss: 0.677. Test acc: 0.583
# Epoch [2/10]. Step [2/2]. Loss: 0.660. Acc: 0.644. Test loss: 0.660. Test acc: 0.650
# Epoch [3/10]. Step [2/2]. Loss: 0.627. Acc: 0.686. Test loss: 0.628. Test acc: 0.689
# Epoch [4/10]. Step [2/2]. Loss: 0.597. Acc: 0.723. Test loss: 0.583. Test acc: 0.717
# Epoch [5/10]. Step [2/2]. Loss: 0.571. Acc: 0.751. Test loss: 0.533. Test acc: 0.711
# Epoch [6/10]. Step [2/2]. Loss: 0.509. Acc: 0.767. Test loss: 0.503. Test acc: 0.728
# Epoch [7/10]. Step [2/2]. Loss: 0.479. Acc: 0.780. Test loss: 0.505. Test acc: 0.739
# Epoch [8/10]. Step [2/2]. Loss: 0.450. Acc: 0.783. Test loss: 0.524. Test acc: 0.761
# Epoch [9/10]. Step [2/2]. Loss: 0.415. Acc: 0.789. Test loss: 0.530. Test acc: 0.761
# Epoch [10/10]. Step [2/2]. Loss: 0.358. Acc: 0.818. Test loss: 0.524. Test acc: 0.767
# Training is finished!
# CPU times: user 3.16 s, sys: 61.3 ms, total: 3.22 s
# Wall time: 3.49 s

# %%
#визуализации функции потерь
plt.title('Loss history')
plt.grid(True)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(train_loss_history, label='train')
plt.plot(valid_loss_history, label='valid')
plt.legend()

# %%
#визуализации метрики
plt.title('Accuracy history')
plt.grid(True)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(train_acc_history_gru, label='train')
plt.plot(valid_acc_history_gru, label='valid')
plt.legend()
